# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("insurance (2).csv")

# %%
data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# 1.Shape of Data

# %%
data.shape
# Out:
# (1338, 7)

# %% [markdown]
# 2.Data type of each attribute

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %% [markdown]
# 3.Number of missing variables

# %%
data.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %% [markdown]
# None of the variables are missing

# %% [markdown]
# 4.Five-Point summary of numerical attributes

# %%
data.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %% [markdown]
# 5.Distribution of Age, bmi and charges

# %%
sns.distplot(data['age'])

# %%
sns.distplot(data['bmi'])

# %%
sns.distplot(data['charges'])

# %% [markdown]
# 6.Measure of skewness

# %%
print("Skewness of age: ",data['age'].skew())
print("Skewness of bmi: ",data['bmi'].skew())
print("Skewness of charges: ",data['charges'].skew())
# Out:
# Skewness of age:  0.05567251565299186
# Skewness of bmi:  0.2840471105987448
# Skewness of charges:  1.5158796580240388

# %% [markdown]
# 7.Checking the presence of outliers in ‘bmi’, ‘age’ and ‘charges column

# %%
sns.boxplot(data['age'])

# %% [markdown]
# We can see there are no outliers

# %%
sns.boxplot(data['bmi'])

# %% [markdown]
# There is a presence of some outliers

# %%
sns.boxplot(data['charges'])

# %% [markdown]
# There are many outliers

# %% [markdown]
# 8.Distribution of categorical columns

# %% [markdown]
# Distribution of Sex

# %%
data['sex'].value_counts().plot(kind='bar')

# %% [markdown]
# Distribution of Children

# %%
data['children'].value_counts().plot(kind='bar')

# %% [markdown]
# Distribution of smokers

# %%
data['smoker'].value_counts().plot(kind='bar')

# %% [markdown]
# Distribution of region

# %%
data['region'].value_counts().plot(kind='bar')

# %% [markdown]
# 9.Pair plot that includes all the columns of the data frame

# %%
sns.pairplot(data)

# %% [markdown]
# 1.Do charges of people who smoke differ significantly from the people who don't ?

# %%
sns.distplot(data[data["smoker"]=="yes"]['charges'])

# %%
sns.distplot(data[data["smoker"]=="no"]['charges'])

# %% [markdown]
# Ans: With enough statistical proof, The charges of smokers and non smokers differ significantly

# %% [markdown]
# 2.Does bmi of males differ significantly from that of females?

# %%
sns.distplot(data[data["sex"]=="male"]['bmi'])

# %%
sns.distplot(data[data["sex"]=="female"]['bmi'])

# %% [markdown]
# Ans: We can see that the BMI of females only differ slightly with males

# %% [markdown]
# 3.Is the proportion of smokers significantly different in different genders?

# %%
data[data["smoker"]=="yes"]['sex'].value_counts().plot(kind='bar')

# %%
data[data["smoker"]=="yes"]['sex'].value_counts()
# Out:
# male      159
# female    115
# Name: sex, dtype: int64

# %% [markdown]
# Ans: Yes. With the given graph , there seems to be a higher number of male smokers. 159/274 which tells us that 54% of smokers
# are male

# %% [markdown]
# 4.Is the distribution of bmi across women with no children, one child and two children, the same?

# %%
sns.distplot(data[data["sex"]=="female"][data["children"]==0]['bmi'])
# Out:
# C:\Users\Jean.DESKTOP-0D64KCL.000\anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %%
sns.distplot(data[data["sex"]=="female"][data["children"]==1]['bmi'])
# Out:
# C:\Users\Jean.DESKTOP-0D64KCL.000\anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %%
sns.distplot(data[data["sex"]=="female"][data["children"]==2]['bmi'])
# Out:
# C:\Users\Jean.DESKTOP-0D64KCL.000\anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# Ans: No the distribution isnt the same. Females with 2 children tend to have bmi over 30. While females with 1 child and no children
# vary , they are close to each other.
